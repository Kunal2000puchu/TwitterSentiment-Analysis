# %%
import tweepy
from textblob import TextBlob
import pandas as pd
import matplotlib.pyplot as plt
import re
from wordcloud import WordCloud
plt.style.use('fivethirtyeight')

# %%
APIkey="PlPYj2O3jdyxtsFMZbNUEchEn"
APISecreatKey="2GsJqKsVimQO3MZgN7gz21Z6rAORDcYe1YgTnHXuFDY8rHcw16"
accessToken="1514933451795087367-SyAI9kistvZAlWlaisSyioRkzfFEDe"
accessTokenSecreat="wSdqQAzL62gnAy5mlytcdy1T5Vadx6xIVFwb1LpmdmGz5"

# %%
authenticate = tweepy.OAuthHandler(APIkey,APISecreatKey)
authenticate.set_access_token(accessToken,accessTokenSecreat)
api= tweepy.API(authenticate)

# %%
posts= api.user_timeline(screen_name='russiaVSukrain',count=100,tweet_mode='extended')
i=1
for tweet in posts[:10]: 
    print(str(i) + ') ' + tweet.full_text + '\n')
    i= i+1
# Out:
# 1) RT @parasguptaaa: Spacex Telecommunications Provider Starlink Internet Speed at Ukraine....
#
# Satellite Internet....
#
# @elonmusk #Ukraine #Uk…
#
# 2) RT @russiavsukrain: Clip 60/N
#
# To understanding Ukraine.....
#
# #Russia #Ukraine #YoungSoldier #NATO #UkraineRussia #RussiaArmy #ukrainianArm…
#
# 3) RT @russiavsukrain: Clip 61/N
#
# Whole summary in one footage....
#
# #Russia #Ukraine #YoungSoldier #NATO #UkraineRussia #RussiaArmy #Ukrainian…
#
# 4) Clip 61/N
#
# Whole summary in one footage....
#
# #Russia #Ukraine #YoungSoldier #NATO #UkraineRussia #RussiaArmy #UkrainianArmy https://t.co/xrXtNTFOgf
#
# 5) Clip 60/N
#
# To understanding Ukraine.....
#
# #Russia #Ukraine #YoungSoldier #NATO #UkraineRussia #RussiaArmy #ukrainianArmy #WWIII https://t.co/rmtJG4HnaA
#
# 6) RT @russiavsukrain: Clip 46/N
#
# !!SUPER EXCLUSIVE!!
#
# Missile on the way
#
# #Russia #Ukraine #YoungSoldier #NATO #UkraineRussia #RussiaArmy #uk…
#
# 7) RT @russiavsukrain: Clip 46/N
#
# Strong Explosion at kharkiv, Ukraine
#
# #Russia #Ukraine #YoungSoldier #NATO #UkraineRussia #RussiaArmy #ukrai…
#
# 8) RT @russiavsukrain: Clip 46/N
#
# Casualties
#
# #Russia #Ukraine #YoungSoldier #NATO #UkraineRussia #RussiaArmy #ukrainianArmy #WWIII https://t.…
#
# 9) RT @russiavsukrain: Clip 45/N
#
# #Russia #Ukraine #YoungSoldier #NATO #UkraineRussia #RussiaArmy #ukrainianArmy #WWIII https://t.co/vfzGOWZ0p7
#
# 10) RT @russiavsukrain: Clip 44/N
#
# Women confronting with russian soldiers.
#
# #Russia #Ukraine #YoungSoldier #NATO #UkraineRussia #RussiaArmy #u…

# %%
analysis=TextBlob("Today was the best day ")

# %%
analysis.sentiment
# Out:
# Sentiment(polarity=1.0, subjectivity=0.3)

# %%
df= pd.DataFrame([tweet.full_text for tweet in posts],columns=['Tweets'])
df
# Out:
#                                                Tweets
# 0   RT @parasguptaaa: Spacex Telecommunications Pr...
# 1   RT @russiavsukrain: Clip 60/N\n\nTo understand...
# 2   RT @russiavsukrain: Clip 61/N\n\nWhole summary...
# 3   Clip 61/N\n\nWhole summary in one footage....\...
# 4   Clip 60/N\n\nTo understanding Ukraine.....\n\n...
# ..                                                ...
# 95  2/n\n\n🇺🇦 #URGENTE #WWIII #Ucrania #UkraineRus...
# 96  🇺🇦 #URGENTE #WWIII #Ucrania #UkraineRussiaConf...
# 97  @minepinetworrk 0xC906011e6F6E29a3989b92a269Dc...
# 98  @minepinetworrk 0xC906011e6F6E29a3989b92a269Dc...
# 99  @minepinetworrk 0xC906011e6F6E29a3989b92a269Dc...
#
# [100 rows x 1 columns]

# %%
def cleanTxt(text):
    text= re.sub('@[A-Za-z0-9]+','',text ) #removing mentions
    text= re.sub("#",'',text) #removing #
    text= re.sub('RT[\s]+','',text) # removing Retweets
    text= re.sub('https?:\/\/\S+','',text) #removing links
    return text

# %%
df['Tweets']= df['Tweets'].apply(cleanTxt)

# %%
df
# Out:
#                                                Tweets
# 0   : Spacex Telecommunications Provider Starlink ...
# 1   : Clip 60/N\n\nTo understanding Ukraine.....\n...
# 2   : Clip 61/N\n\nWhole summary in one footage......
# 3   Clip 61/N\n\nWhole summary in one footage....\...
# 4   Clip 60/N\n\nTo understanding Ukraine.....\n\n...
# ..                                                ...
# 95  2/n\n\n🇺🇦 URGENTE WWIII Ucrania UkraineRussiaC...
# 96  🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict...
# 97   0xC906011e6F6E29a3989b92a269DcC5729d252551\nG...
# 98         0xC906011e6F6E29a3989b92a269DcC5729d252551
# 99         0xC906011e6F6E29a3989b92a269DcC5729d252551
#
# [100 rows x 1 columns]

# %%
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# create a function to get the Polarity of all the tweets
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# create 2 columns 'Subjectivity' and 'Polarity'
df['Subjectivity']= df['Tweets'].apply(getSubjectivity)
df['Polarity']= df['Tweets'].apply(getPolarity)

# %%
dff
# Out:
#                                                Tweets  Subjectivity  Polarity
# 0   : Spacex Telecommunications Provider Starlink ...      0.000000  0.000000
# 1   : Clip 60/N\n\nTo understanding Ukraine.....\n...      0.000000  0.000000
# 2   : Clip 61/N\n\nWhole summary in one footage......      0.400000  0.200000
# 3   Clip 61/N\n\nWhole summary in one footage....\...      0.400000  0.200000
# 4   Clip 60/N\n\nTo understanding Ukraine.....\n\n...      0.000000  0.000000
# ..                                                ...           ...       ...
# 95  2/n\n\n🇺🇦 URGENTE WWIII Ucrania UkraineRussiaC...      0.000000  0.000000
# 96  🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict...      0.000000  0.000000
# 97   0xC906011e6F6E29a3989b92a269DcC5729d252551\nG...      0.783333  0.766667
# 98         0xC906011e6F6E29a3989b92a269DcC5729d252551      0.000000  0.000000
# 99         0xC906011e6F6E29a3989b92a269DcC5729d252551      0.000000  0.000000
#
# [100 rows x 3 columns]

# %%
def getAnalysis(score):
    if score<0:
        return 'Negative'
    elif score==0:
        return 'Neutral'
    else:
        return 'Positive'

df['Analysis']= df['Polarity'].apply(getAnalysis)
df
# Out:
#                                                Tweets  Subjectivity  Polarity  \
# 0   : Spacex Telecommunications Provider Starlink ...      0.000000  0.000000
# 1   : Clip 60/N\n\nTo understanding Ukraine.....\n...      0.000000  0.000000
# 2   : Clip 61/N\n\nWhole summary in one footage......      0.400000  0.200000
# 3   Clip 61/N\n\nWhole summary in one footage....\...      0.400000  0.200000
# 4   Clip 60/N\n\nTo understanding Ukraine.....\n\n...      0.000000  0.000000
# ..                                                ...           ...       ...
# 95  2/n\n\n🇺🇦 URGENTE WWIII Ucrania UkraineRussiaC...      0.000000  0.000000
# 96  🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict...      0.000000  0.000000
# 97   0xC906011e6F6E29a3989b92a269DcC5729d252551\nG...      0.783333  0.766667
# 98         0xC906011e6F6E29a3989b92a269DcC5729d252551      0.000000  0.000000
# 99         0xC906011e6F6E29a3989b92a269DcC5729d252551      0.000000  0.000000
#
#     Analysis
# 0    Neutral
# 1    Neutral
# 2   Positive
# 3   Positive
# 4    Neutral
# ..       ...
# 95   Neutral
# 96   Neutral
# 97  Positive
# 98   Neutral
# 99   Neutral
#
# [100 rows x 4 columns]

# %%
df[df['Analysis']=='Neutral']
# Out:
#                                                Tweets  Subjectivity  Polarity  \
# 0   : Spacex Telecommunications Provider Starlink ...           0.0       0.0
# 1   : Clip 60/N\n\nTo understanding Ukraine.....\n...           0.0       0.0
# 4   Clip 60/N\n\nTo understanding Ukraine.....\n\n...           0.0       0.0
# 7   : Clip 46/N\n\nCasualties\n\nRussia Ukraine Yo...           0.0       0.0
# 8   : Clip 45/N\n\nRussia Ukraine YoungSoldier NAT...           0.0       0.0
# ..                                                ...           ...       ...
# 94  3/n\n\n🇺🇦 URGENTE WWIII Ucrania UkraineRussiaC...           0.0       0.0
# 95  2/n\n\n🇺🇦 URGENTE WWIII Ucrania UkraineRussiaC...           0.0       0.0
# 96  🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict...           0.0       0.0
# 98         0xC906011e6F6E29a3989b92a269DcC5729d252551           0.0       0.0
# 99         0xC906011e6F6E29a3989b92a269DcC5729d252551           0.0       0.0
#
#    Analysis
# 0   Neutral
# 1   Neutral
# 4   Neutral
# 7   Neutral
# 8   Neutral
# ..      ...
# 94  Neutral
# 95  Neutral
# 96  Neutral
# 98  Neutral
# 99  Neutral
#
# [70 rows x 4 columns]

# %%
df['Analysis'].value_counts()
# Out:
# Neutral     70
# Positive    25
# Negative     5
# Name: Analysis, dtype: int64

# %%
df.shape
# Out:
# (100, 4)

# %%
plt.figure(figsize=(8,6))
for i in range(0,df.shape[0]):
    plt.scatter(df['Polarity'][i],df['Subjectivity'][i],color='Blue')
    
plt.title("Sentiment Analysis")
plt.xlim(-1,1)
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.show()

# %%
df['Analysis'].value_counts().plot(kind='bar')
plt.title("Sentiment Analysis")
plt.xlabel('Polarity')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # POSITIVE TWEET ONLY

# %%
i=1
sortedDF = df.sort_values(by=['Polarity'],ascending=False)
for j in range(0,sortedDF.shape[0]):
    if (sortedDF['Analysis'][j]=='Positive'):
        print(str(i)+ ') ' + sortedDF['Tweets'][j])
        print()
        i=i+1
# Out:
# 1) : Clip 61/N
#
# Whole summary in one footage....
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy Ukrainian…
#
# 2) Clip 61/N
#
# Whole summary in one footage....
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy UkrainianArmy
#
# 3) : Clip 46/N
#
# !!SUPER EXCLUSIVE!!
#
# Missile on the way
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy uk…
#
# 4) : Clip 46/N
#
# Strong Explosion at kharkiv, Ukraine
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrai…
#
# 5) Clip 53/N
#
# !!SUPER EXCLUSIVE!!
#
# Missile on the way
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrainianArmy WWIII
#
# 6) Clip 46/N
#
# !!SUPER EXCLUSIVE!!
#
# Missile on the way
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrainianArmy WWIII
#
# 7) Clip 46/N
#
# Strong Explosion at kharkiv, Ukraine
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrainianArmy WWIII
#
# 8) Clip 39/N
# An young 18 year old Russian Soldier captured by Ukraine Army.
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrainianArmy WWIII
#
# 9) : Clip 37/n
#
# Combat near Chernobyl nuclear plant
#
#  worldwar3
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukrain…
#
# 10) Clip 37/n
#
# Combat near Chernobyl nuclear plant
#
#  worldwar3
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 11) Clip 34/n
#
# Ukrainian forces blew up their own bridge over the Oskol river to block the Russian advance.
#
# Ukraina Russia RussiaUkraine RussiaUkraineConflict worldwar3 UkraineRussiaConflict WWlll
#
# 12) : Clip 31/n
#
# !!SUPER EXCLUSIVE!!
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 13) : Clip 30/n
#
# !!SUPER EXCLUSIVE!!
#
# Missile attack Ukraine.....
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine…
#
# 14) : Clip 28/n
#
# !!SUPER EXCLUSIVE!!
#
# Missile defence system clear video.....
#
# URGENTE WWIII Ucrania UkraineRussiaConfli…
#
# 15) Clip 30/n
#
# !!SUPER EXCLUSIVE!!
#
# Missile attack Ukraine.....
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 16) Clip 31/n
#
# !!SUPER EXCLUSIVE!!
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 17) : Clip 26/n
#
# !!SUPER EXCLUSIVE!!
#
# Ware house near Ukraine border....
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  …
#
# 18) Clip 29/n
#
# !!SUPER EXCLUSIVE!!
#
# Tank crossing Russian border.....
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 19) Clip 28/n
#
# !!SUPER EXCLUSIVE!!
#
# Missile defence system clear video.....
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 20) : Clip 26/n
#
# !!SUPER EXCLUSIVE!!
#
# Village near Ukraine border....
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukr…
#
# 21) Clip 26/n
#
# !!SUPER EXCLUSIVE!!
#
# Ware house near Ukraine border....
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 22) Clip 26/n
#
# !!SUPER EXCLUSIVE!!
#
# Village near Ukraine border....
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 23)  Yes i upload after cross check.... No fake videos
#
# 24)  No it's real... I cross checked it
#
# 25)  0xC906011e6F6E29a3989b92a269DcC5729d252551
# Great project i love pi network soo much💖💖and i joined pi network from 2 year ago and i believe that pi network will go to the moon and the time is comming im very happy from pi network team

# %% [markdown]
# # NEGATIVE TWEET ONLY

# %%
i=1
sortedDF = df.sort_values(by=['Polarity'],ascending=False)
for j in range(0,sortedDF.shape[0]):
    if (sortedDF['Analysis'][j]=='Negative'):
        print(str(i)+ ') ' + sortedDF['Tweets'][j])
        print()
        i=i+1
# Out:
# 1) Clip 36/n
#
# Vladimir Putin warns Joe Biden in case of external interference in the Russia-Ukraine conflict: "Our people must know that Russia response will be immediate and will lead to consequences that you have never experienced in your history."
#
# Russia  USA Putin JoeBiden
#
# 2) Clip 35/n
#
# Ukrainian post at Snake Island in the Black Sea told Russian warship to "go f*** yourself" after being told to surrender. The 13 service members were killed.
#
# Russia Ukraine SnakeIsland BlackSea RussiaUkraineCrisis RussiaUkraineConflict  WWIII
#
# 3)  Internet issue sorry......
#
# 4) Clip 20/n
#
# Missile attack on car accused 14 year girld lead to death.... This is terrible
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 5)  Not nuclear.... It's keyword in wrong place

# %% [markdown]
# # NEUTRAL TWEET ONLY

# %%
i=1
sortedDF = df.sort_values(by=['Polarity'],ascending=False)
for j in range(0,sortedDF.shape[0]):
    if (sortedDF['Analysis'][j]=='Neutral'):
        print(str(i)+ ') ' + sortedDF['Tweets'][j])
        print()
        i=i+1
# Out:
# 1) : Spacex Telecommunications Provider Starlink Internet Speed at Ukraine....
#
# Satellite Internet....
#
#  Ukraine Uk…
#
# 2) : Clip 60/N
#
# To understanding Ukraine.....
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrainianArm…
#
# 3) Clip 60/N
#
# To understanding Ukraine.....
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrainianArmy WWIII
#
# 4) : Clip 46/N
#
# Casualties
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrainianArmy WWIII
#
# 5) : Clip 45/N
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrainianArmy WWIII
#
# 6) : Clip 44/N
#
# Women confronting with russian soldiers.
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy u…
#
# 7) : Clip 43/N
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrainianArmy WWIII
#
# 8) : Clip 42/N
#
# Ukrainian Helicopter Attack
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrainianArmy…
#
# 9) : Clip 40/N
#
# Footage moments before Ukrainian soldiers defending Serpent Island are targeted by a Russian warship
#
# Russ…
#
# 10) : Clip 41/N
#
# Russian soldiers shoot at the civilian car, injuring 2 people inside the car. The video was taken from insid…
#
# 11) Pic 3/N
#
# They might not come....😭😭
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrainianArmy WWIII
#
# 12) Clip 46/N
#
# Casualties
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrainianArmy WWIII
#
# 13) Clip 45/N
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrainianArmy WWIII
#
# 14) Clip 44/N
#
# Women confronting with russian soldiers.
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrainianArmy WWIII
#
# 15) Clip 43/N
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrainianArmy WWIII
#
# 16) Clip 42/N
#
# Ukrainian Helicopter Attack
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrainianArmy WWIII
#
# 17) Clip 41/N
#
# Russian soldiers shoot at the civilian car, injuring 2 people inside the car. The video was taken from inside the car.
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrainianArmy WWIII
#
# 18) Clip 40/N
#
# Footage moments before Ukrainian soldiers defending Serpent Island are targeted by a Russian warship
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy UkrainianArmy WWIII
#
# 19) Clip 38/N
#
# Moment rocket hits the ground in a street in Kiev city but doesn’t explode.
#
# Russia Ukraine YoungSoldier NATO UkraineRussia RussiaArmy ukrainianArmy
#
# 20) : Clip 37/n
#
# CNN team witnessed a firefight outside Kyiv:
#
# Russia Ukraine RussiaUkraine RussiaUkraineCrisis Kyiv CN…
#
# 21) Pic 2/n
#
# Ukraine Nato
#
# Earth is just tiny dot in this universe.
#
# Please say no to war.
#
#  worldwar3
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 22) Clip 36/n
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 23) : Clip 36/n
#
# Vladimir Putin warns Joe Biden in case of external interference in the Russia-Ukraine conflict: "Our people…
#
# 24) Clip 37/n
#
# CNN team witnessed a firefight outside Kyiv:
#
# Russia Ukraine RussiaUkraine RussiaUkraineCrisis Kyiv CNN CNNReport CNNNews
#
# 25) : Pic 1/n
#
# Anti-war protestors in St Petersburg, Russia.
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Uc…
#
# 26) : Clip 33/n
#
# Ukrainian army hits to Russian troops
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania…
#
# 27) Clip 33/n
#
# Ukrainian army hits to Russian troops
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 28) Pic 1/n
#
# Anti-war protestors in St Petersburg, Russia.
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 29) Clip 32/n
#
# Anti-war protestors in St Petersburg, Russia.
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 30)  May jesus give him some emotions...
#
# 31) O uploaded it after cross check....
#
# 32) : Clip 24/N
#
# !!EXCLUSIVE!!
#
# Missile attack on Ukraine....
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucr…
#
# 33) : Clip 25/N
#
# !!EXCLUSIVE!!
#
# MI-8 avaiding surface-to-air missile (Vyshgorod, 20kn from Kyiv)
#
# Missile attack on Ukraine.…
#
# 34) : Clip 23/n
#
# Missile attack on ukraine....
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 35) Clip 25/N
#
# !!EXCLUSIVE!!
#
# MI-8 avaiding surface-to-air missile (Vyshgorod, 20kn from Kyiv)
#
# Missile attack on Ukraine....
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
# MI-8 avaiding surface-to-air missile (Vyshgorod, 20kn from Kyiv)
#
# 36) Clip 24/N
#
# !!EXCLUSIVE!!
#
# Missile attack on Ukraine....
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
# MI-8 avaiding surface-to-air missile (Vyshgorod, 20kn from Kyiv)
#
# 37) Clip 23/n
#
# Missile attack on ukraine....
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 38) Clip 22/n
#
# Missile attack ....
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 39) Clip 21/n
#
# Bombing Caught On Twitch.....
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania No_WAR
#
# 40)  Littrelly
#
# 41) Clip 19/n
#
# Missile attack....
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 42) Clip 18/n
#
# Missile attack....
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 43) Clip 17/n
#
# Missile attack on airport....
#
# URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 44) Clip 16/n
#
# Barrage of Russian rockets landing in Kharkiv, Ukraine.
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 45) Clip 15/n
#
# Presumably missile attack just hit Kyiv, Ukraine
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 46) : Clip 14/n
#
# Missile attack on airport.... Nuclear
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania…
#
# 47) : Clip 13/n
#
# Missile attack on airport.... Nuclear
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania…
#
# 48) : Clip 12/n
#
# Missile attack on airport.... Nuclear
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania…
#
# 49) : Clip 11/n
#
# Missile attack on airport.... Nuclear
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania…
#
# 50) : Clip 10/n
#
# Missile
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania  https:…
#
# 51) : Clip 9/n
#
# Missile over News Reporter
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 52) : Clip 8/n
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 53) : Clip 7/n
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 54) : Clip 6/n
#
# Missile defence on
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 55) Clip 14/n
#
# Missile attack on airport.... Nuclear
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 56) Clip 13/n
#
# Missile attack on airport.... Nuclear
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 57) Clip 12/n
#
# Missile attack on airport.... Nuclear
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 58) Clip 11/n
#
# Missile attack on airport.... Nuclear
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 59) Clip 10/n
#
# Missile
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 60) Clip 9/n
#
# Missile over News Reporter
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 61) Clip 8/n
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 62) Clip 7/n
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 63) Clip 6/n
#
# Missile defence on
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 64) Clip 5/n
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 65) Clip 4/n
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 66) 3/n
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine Ucrania
#
# 67) 2/n
#
# 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine
#
# 68) 🇺🇦 URGENTE WWIII Ucrania UkraineRussiaConflict  Ukraine krainian media reports that explosions are heard in Kiev, Kramatorsk, Odessa, Kharkov, Berdyansk, as well as in the area of ​​the Kiev Boryspil airport......
#
# 69)  0xC906011e6F6E29a3989b92a269DcC5729d252551
#
# 70)  0xC906011e6F6E29a3989b92a269DcC5729d252551

# %%
allwords= ' '.join([i for i in df['Tweets']])
Cloud= WordCloud(width=500,height=300,random_state=0,max_font_size=100).generate(allwords)

plt.imshow(Cloud)
plt.show()
